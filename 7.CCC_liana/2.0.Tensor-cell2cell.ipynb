# %% [markdown]
# # TENSOR CELL 2 CELL #

# %% [markdown]
# This script has been run in Google Collab in order to use Google's GPU dependencies.

# %%
# %pip install decoupler
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 47.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 97.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 5.5 MB/s eta 0:00:00
# ...
#   Created wheel for docrep: filename=docrep-0.3.2-py3-none-any.whl size=19876 sha256=d9b2be8e7ec1835ca137cade9224d16fb4a97a877708fbb09178356789b699dc
# ...

# %%
# %pip install cell2cell
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 56.7 MB/s eta 0:00:00
# ...

# %%
# %pip install liana
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 70.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 17.5 MB/s eta 0:00:00
# ...

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.9.0
# adjustText                            1.3.0
# aiofiles                              24.1.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.12.14
# aiosignal                             1.4.0
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.11.2
# altair                                5.5.0
# anndata                               0.12.1
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.9.0
# anywidget                             0.9.18
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  21.2.0
# ...

# %%
import cell2cell as c2c
import liana as li

import numpy as np
import pandas as pd

# %%
use_gpu = True

if use_gpu:
    import tensorly as tl
    tl.set_backend('pytorch')

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import decoupler as dc
import scanpy as sc

import plotnine as p9
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import logging
logging.disable(logging.WARNING) # This is to avoid too many logs because of GSEApy

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_files="/content/drive/MyDrive/tfm/"

# %%
tensor = c2c.io.read_data.load_tensor(path_files + 'data/Tensor.pkl')
meta_tensor = c2c.io.load_variable_with_pickle(path_files + '/data/Tensor-Metadata.pkl')

# %%
c2c.analysis.run_tensor_cell2cell_pipeline(tensor,
                                           meta_tensor,
                                           rank=None, # Number of factors to perform the factorization. If None, it is automatically determined by an elbow analysis
                                           tf_optimization='robust', # To define how robust we want the analysis to be.
                                           random_state=0, # Random seed for reproducibility
                                           device='cuda', # Device to use. If using GPU and PyTorch, use 'cuda'. For CPU use 'cpu'
                                           output_folder=path_files, # Whether to save the figures in files. If so, a folder pathname must be passed
                                          )
# Out:
# Running Elbow Analysis
# 100%|██████████| 25/25 [1:06:19<00:00, 159.17s/it]
# The rank at the elbow is: 12
# Running Tensor Factorization
# 100%|██████████| 100/100 [12:22<00:00,  7.43s/it]
# Best model has a normalized error of: 0.504
# Generating Outputs
# Loadings of the tensor factorization were successfully saved into /content/drive/MyDrive/tfm//Loadings.xlsx

# %%
import pickle

with open('/content/drive/MyDrive/tfm/data/tensor_with_loadings_cell2cell_12f.pkl', 'wb') as f:
    pickle.dump(tensor, f)
